% %%
function plotData(X, y, xText, yText)
    figure; % open a new figure
    plot(X, y, 'ob'); %Plot the data in blue circles
    ylabel(yText); % Set the y−axis label 
    xlabel(xText); % Set the x−axis label

    figure; % open a new figure
    plot(X, y, '*g'); %Plot the data in green asterisks
    ylabel(yText); % Set the y−axis label 
    xlabel(xText); % Set the x−axis label

    figure; % open a new figure
    plot(X, y, 'dr'); %Plot the data in red diamonds
    ylabel(yText); % Set the y−axis label 
    xlabel(xText); % Set the x−axis label
endfunction

% %%
function cost = computeCost(X, y, theta, lambdaParameter)
    dataLength = length(y);
    cost = 0;
    
    for i = 1:dataLength
        hypothesis = theta(1) + theta(2) * X(i);
        cost = cost + (hypothesis - y(i))^2;
    endfor
    cost = cost / (2 * dataLength + 2 * (lambdaParameter * (theta(1)^2 + theta(2)^2)));
%     cost = cost );
endfunction

% %%
function plotRMSE(rmse, iterations)
    figure; % open a new figure
    plot(rmse(1:iterations));
    ylabel("RMSE"); % Set the y−axis label 
    xlabel("Iteration"); % Set the x−axis label
endfunction

% %%
function plotLinearModel(X_data, y, theta, xText, yText)
    figure;
    plot(X_data, y, 'dr');
    ylabel(xText);
    xlabel(yText);
    
    X = [ones(length(y), 1), X_data];
    
    hold on;
    plot(X_data, X*theta, "-");
    legend('Training data', "Linear regression");
    hold off;
endfunction

% %%
function [theta, rmse] = gradientDescent(X_data, y_data, lambdaParameter)
    dataLength = length(y_data);
    X = [ones(dataLength, 1), X_data];
    
    theta = zeros(2, 1);
    
    iterations = 1500;
    alpha = 0.01;
    
    initialCost = computeCost(X_data, y_data, theta, lambdaParameter);
    
    rmse = zeros(iterations);
    
    printf("Initial cost: %f\n", initialCost);
    
    for iter = 1:iterations
        if(mod(iter, 100) == 0)
            printf("Costo %f Iter: %i\n", computeCost(X_data, y_data, theta, lambdaParameter), iter);
        endif
        
        temp1 = 0;
        temp2 = 0;
        
        batchMSE = 0;
        for i = 1:dataLength
            hypothesis = theta(1) + theta(2) * X(i, 2);
            temp1 = temp1 + (hypothesis - y_data(i));
            temp2 = temp2 + ((hypothesis - y_data(i)) * X(i, 2));
            batchMSE = batchMSE + ((hypothesis - y_data(i))^2);
        endfor
        
        batchMSE = batchMSE / dataLength;
        rmse(iter) = batchMSE^(1/2);
        
        temp1 = temp1 * alpha / dataLength;
        temp2 = temp2 * alpha / dataLength;
        
        theta(1) = (theta(1) * (1 - alpha * (lambdaParameter / dataLength))) - temp1;
        theta(2) = (theta(2)) * (1 - alpha * (lambdaParameter / dataLength)) - temp2;
    endfor
    
    printf("Optimal theta: %f, %f\n", theta(1), theta(2));
endfunction

% %%
function visualizeParameters(X, y, theta, lambdaParameter)
    % Grid over which we will calculate J
    theta0_vals = linspace(-10, 10, 100);
    theta1_vals = linspace(-1, 4, 100);

    % initialize J_vals to a matrix of 0's
    J_vals = zeros(length(theta0_vals), length(theta1_vals));

    % Fill out J_vals
    for i = 1:length(theta0_vals)
        for j = 1:length(theta1_vals)
          t = [theta0_vals(i); theta1_vals(j)];    
          J_vals(i,j) = computeCost(X, y, t, lambdaParameter);
        end
    end
    
    % Because of the way meshgrids work in the surf command, we need to 
    % transpose J_vals before calling surf, or else the axes will be flipped
    J_vals = J_vals';
    % Surface plot
    figure;
    surf(theta0_vals, theta1_vals, J_vals)
    xlabel('\theta_0'); ylabel('\theta_1');

    % Contour plot
    figure;
    % Plot J_vals as 15 contours spaced logarithmically between 0.01 and 100
    contour(theta0_vals, theta1_vals, J_vals, logspace(-2, 3, 20))
    xlabel('\theta_0'); ylabel('\theta_1');
    hold on;
    plot(theta(1), theta(2), 'rx', 'MarkerSize', 10, 'LineWidth', 2);
    
endfunction

% %%
function compute(X, y, xText, yText, lambdaParameters)
    fprintf('Plotting Data ...\n');
    plotData(X, y, xText, yText);
    
    for i = 1:length(lambdaParameters)
        
        printf("Calculating gradientDescent with lambda %i\n", lambdaParameters(i));
        [theta, rmse] = gradientDescent(X, y, lambdaParameters(i));
        
        printf("Plotting RMSE \n");
        plotRMSE(rmse, length(y));
        
        printf("Plotting Linear model\n");
        plotLinearModel(X, y, theta, "X", "Y");
        
        printf("Plotting parameters\n");
        visualizeParameters(X, y, theta, lambdaParameters(i));
    endfor
endfunction

% %%
ex1_data = load('ex1/ex1data1.txt');
ex1_X = ex1_data(:, 1);
ex1_y = ex1_data(:, 2);
% ex1_size = length(ex1_y);

% fprintf('Plotting Data ...\n');
% plotData(ex1_X, ex1_y, "Population of City in 10,000s", "Profit in $10,000s");

compute(ex1_X, ex1_y, "Population of city in 10,000s", "Profit in $10,000s", [0,1,2]);
% Out:
% Plotting Data ...
% Calculating gradientDescent with lambda 0
% Initial cost: 32.072734
% Costo 5.483601 Iter: 100
% Costo 5.178680 Iter: 200
% Costo 4.966124 Iter: 300
% Costo 4.817953 Iter: 400
% Costo 4.714666 Iter: 500
% Costo 4.642665 Iter: 600
% Costo 4.592474 Iter: 700
% Costo 4.557487 Iter: 800
% Costo 4.533098 Iter: 900
% Costo 4.516096 Iter: 1000
% Costo 4.504245 Iter: 1100
% Costo 4.495983 Iter: 1200
% Costo 4.490224 Iter: 1300
% Costo 4.486210 Iter: 1400
% Costo 4.483411 Iter: 1500
% Optimal theta: -3.630291, 1.166362Plotting RMSE
% Plotting Linear model
% Plotting parameters

% %%
compute(1,1,"x","y", [1,2,3,4,10]);
% Out:
% 1
% 2
% 3
% 4
% 10

% %%
[ex1_theta, ex1_rmse] = gradientDescent(ex1_X, ex1_y, 0);
% Out:
% Initial cost: 32.072734
% Costo 5.483601 Iter: 100
% Costo 5.178680 Iter: 200
% Costo 4.966124 Iter: 300
% Costo 4.817953 Iter: 400
% Costo 4.714666 Iter: 500
% Costo 4.642665 Iter: 600
% Costo 4.592474 Iter: 700
% Costo 4.557487 Iter: 800
% Costo 4.533098 Iter: 900
% Costo 4.516096 Iter: 1000
% Costo 4.504245 Iter: 1100
% Costo 4.495983 Iter: 1200
% Costo 4.490224 Iter: 1300
% Costo 4.486210 Iter: 1400
% Costo 4.483411 Iter: 1500
% Optimal theta: -3.630291, 1.166362
% Optimal theta: -3.630291, 1.166362

% %%
plotRMSE(ex1_rmse, length(ex1_y));

% %%
plotLinearModel(ex1_X, ex1_y, ex1_theta, "X", "Y");

% %%
visualizeParameters(ex1_X, ex1_y, ex1_theta, 0);

% %%
[ex1_theta_reg1, ex1_rmse_reg1]  = gradientDescent(ex1_X, ex1_y, 50);
% Out:
% Initial cost: 32.072734
% Costo 3.810495 Iter: 100
% Costo 3.309292 Iter: 200
% Costo 3.054019 Iter: 300
% Costo 2.929030 Iter: 400
% Costo 2.867669 Iter: 500
% Costo 2.837379 Iter: 600
% Costo 2.822371 Iter: 700
% Costo 2.814921 Iter: 800
% Costo 2.811219 Iter: 900
% Costo 2.809378 Iter: 1000
% Costo 2.808462 Iter: 1100
% Costo 2.808006 Iter: 1200
% Costo 2.807780 Iter: 1300
% Costo 2.807667 Iter: 1400
% Costo 2.807611 Iter: 1500
% Optimal theta: -0.950778, 0.892182
% Optimal theta: -0.950778, 0.892182

% %%
plotRMSE(ex1_rmse_reg1, length(ex1_y))

% %%
plotLinearModel(ex1_X, ex1_y, ex1_theta_reg1, "X", "Y");

% %%
visualizeParameters(ex1_X, ex1_y, ex1_theta_reg1, 50);

% %%
devi = csvread('devi.csv');
devi_X = devi(2:end, 3);
devi_y = devi(2:end, 4);
fprintf('Plotting Data ...\n');
plotData(devi_X, devi_y, "n", "devi");
% Out:
% Plotting Data ...

% %%
% gradientDescent(devi_X, devi_y);

% %%
log(devi_X)
% Out:
% ans =
%
%     4.1271
%     4.9200
%     4.4067
%     8.0117
%     5.3132
%     7.4037
%     4.5539
%     4.5218
%     4.9836
%     8.3236
%     5.2730
%     4.8598
%     4.6347
%     6.5737
%     5.7807
%     7.8629
%     5.2679
%     6.0307
%     6.9276
%     6.5793
%     4.4308
%     4.4659
%     5.2575
%     5.4072
%     5.3033
%     4.4773
%     4.5539
%     4.0775
%     5.1180
%     6.7662
%     8.5606
%     5.1818
%     8.0437
%     5.0499
%     6.2519
%     3.9512
%     8.4705
%     6.3117
%     6.9108
%     8.1412
%     5.8081
%     6.6958
%     8.7535
%     4.4659
%     4.5850
%     6.4135
%     6.1485
%     6.6516
%     5.4027
%     5.2417
%     6.4085
%     8.4407
%     4.7095
%     8.2414
%     5.7557
%     5.6348
%     7.3908
%     4.9628
%     8.4892
%     5.8201
%     7.3871
%     6.8967
%     4.4427
%     7.4396
%     3.9703
%     6.1591
%     4.4188
%     4.0073
%     6.2672
%     6.3886
%     5.7170
%     7.4950
%     6.0521
%     5.4806
%     3.9890
%     7.4442
%     6.6631
%     7.4776
%     7.0639
%     6.4036
%     6.5596
%     4.5109
%     7.2869
%     8.9215
%     7.4236
%     5.4337
%     5.0434
%     7.3614
%     6.4151
%     4.2047
%     3.9318
%     4.9904
%     4.6540
%     5.0370
%     5.2470
%     5.2983
%     4.5539
%     5.0370
%     5.2470
%     4.3820
%     3.9318
%     7.0544
%     5.3083
%     6.9422
%     8.2548
%     6.6695
%     6.7334
%     4.6250
%     4.9127
%     5.2883
%     6.1463
%     5.2095
%     7.8200
%     5.9026
%     4.2341
%     4.7958
%     5.8201
%     4.1271
%     4.4773
%     4.6821
%     5.2575
%     5.4467
%     4.3041
%     4.0254
%     6.0822
%     5.1591
%     4.9200
%     5.3753
%     6.2126
%     4.6728
%     4.7362
%     7.9204
%     5.9636
%     4.4773
%     3.9703
%     3.9512
%     5.3471
%     4.4773
%     4.4427
%     4.7707
%     4.7362
%     5.0173
%     5.0304
%     5.8721
%     3.9318
%     6.8437
%     5.6276
%     4.2341
%     5.4161
%     5.1240
%     5.2983
%     8.1365
%     4.2905
%     5.3181
%     4.6052
%     7.3330
%     5.7430
%     4.1589
%     6.7250
%     7.5055
%     5.7301
%     4.7185
%     4.4886
%     8.2592
%     4.2047
%     4.5218
%     4.1897
%     4.9628
%     5.6454
%     4.4659
%     4.3438
%     6.3886
%     7.5491
%     5.0173
%     4.0604
%     3.9512
%     4.7536
%     7.8067
%     8.2938
%     4.0431
%     4.9698
%     5.2832
%     6.0426
%     6.0039
%     6.4800
%     5.3230
%     4.4067
%     6.0568
%     4.0943
%     6.1269
%     4.9558
%     5.7038
%     7.1277
%     5.8319
%     6.3818
%     5.5013
%     4.3041
%     6.3902
%     4.3438
%     6.1092
%     6.2558
%     4.4543
%     4.5326
%     3.9703
%     4.6540
%     5.8749
%     5.1475
%     4.7185
%     5.4250
%     8.9808
%     5.0239
%     4.7185
%     7.9967
%     6.1800
%     6.5250
%     4.1431
%     4.5747
%     8.8621
%     7.3330
%     4.8122
%     4.7536
%     7.0094
%     4.3175
%     5.8141
%     5.0752
%     5.9738
%     4.7536
%     4.4659
%     3.9703
%     6.4877
%     4.6634
%     5.1417
%     5.8493

% %%
fprintf('Plotting Data ...\n');
plotData(log(devi_X), log(devi_y), "n", "devi");
% Out:
% Plotting Data ...

% %%
gradientDescent(log(devi_X), log(devi_y), 0);
% Out:
% Initial cost: 39.145029
% Costo 0.440143 Iter: 100
% Costo 0.410822 Iter: 200
% Costo 0.384397 Iter: 300
% Costo 0.360583 Iter: 400
% Costo 0.339121 Iter: 500
% Costo 0.319780 Iter: 600
% Costo 0.302349 Iter: 700
% Costo 0.286641 Iter: 800
% Costo 0.272484 Iter: 900
% Costo 0.259726 Iter: 1000
% Costo 0.248229 Iter: 1100
% Costo 0.237867 Iter: 1200
% Costo 0.228529 Iter: 1300
% Costo 0.220114 Iter: 1400
% Costo 0.212530 Iter: 1500
% Optimal theta: -2.139481, -1.133852
% Optimal theta: -2.139481, -1.133852
